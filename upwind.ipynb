# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas

# %%
G = 11
L = 1
u = 1
k = 1
h = L/(G-1)
alpha = u*h/(2*k);
alpha
# Out:
# 0.05

# %%
df = pandas.read_csv("./build/data.csv")
X = df['x'].to_numpy()
U = df['u'].to_numpy()
dU = df['du'].to_numpy()

# %%
S = (1-np.exp(u/k*X))/(1-np.exp(u*L/k))
#S = X*(X-1)/2
plt.plot(X,U+X/L)
plt.plot(X,S)
